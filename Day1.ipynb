# %% [markdown]
# # --- Day 1: Sonar Sweep ---
# Advent of Code 2021

# %% [markdown]
# ## Part 1

# %%
with open ("input/day1.1.txt") as f:
    data = f.readlines()

# %%
data = [int(number) for number in data]

# %%
increased = 0

for i in range(1,len(data)):
    print(f"Depth measurement #{i}")
    print(f"{data[i-1]} --> {data[i]}")
    if data[i] - data[i-1] > 0:
        print("(increased)")
        increased += 1
    elif data[i] - data[i-1] < 0:
        print("(decreased)")
    else:
        print("(same)")
    print()
# Out:
# Depth measurement #1
# 183 --> 185
# (increased)
#
# Depth measurement #2
# 185 --> 186
# (increased)
#
# Depth measurement #3
# 186 --> 182
# (decreased)
#
# Depth measurement #4
# 182 --> 185
# (increased)
#
# Depth measurement #5
# 185 --> 191
# (increased)
#
# Depth measurement #6
# 191 --> 204
# (increased)
#
# Depth measurement #7
# 204 --> 203
# (decreased)
#
# Depth measurement #8
# 203 --> 205
# (increased)
#
# Depth measurement #9
# 205 --> 220
# (increased)
#
# Depth measurement #10
# 220 --> 215
# (decreased)
#
# Depth measurement #11
# 215 --> 208
# (decreased)
#
# Depth measurement #12
# 208 --> 216
# (increased)
#
# Depth measurement #13
# 216 --> 217
# (increased)
#
# Depth measurement #14
# 217 --> 218
# (increased)
#
# Depth measurement #15
# 218 --> 219
# (increased)
#
# Depth measurement #16
# 219 --> 210
# (decreased)
#
# Depth measurement #17
# 210 --> 226
# (increased)
#
# Depth measurement #18
# 226 --> 227
# (increased)
#
# Depth measurement #19
# 227 --> 231
# (increased)
#
# Depth measurement #20
# 231 --> 245
# (increased)
#
# Depth measurement #21
# 245 --> 243
# (decreased)
#
# Depth measurement #22
# 243 --> 255
# (increased)
#
# Depth measurement #23
# 255 --> 257
# (increased)
#
# Depth measurement #24
# 257 --> 250
# (decreased)
#
# Depth measurement #25
# 250 --> 255
# (increased)
#
# Depth measurement #26
# 255 --> 286
# (increased)
#
# Depth measurement #27
# 286 --> 287
# (increased)
#
# Depth measurement #28
# 287 --> 286
# (decreased)
#
# Depth measurement #29
# 286 --> 293
# (increased)
#
# Depth measurement #30
# 293 --> 294
# (increased)
#
# Depth measurement #31
# 294 --> 296
# (increased)
#
# Depth measurement #32
# 296 --> 299
# (increased)
#
# Depth measurement #33
# 299 --> 316
# (increased)
#
# Depth measurement #34
# 316 --> 322
# (increased)
#
# Depth measurement #35
# 322 --> 330
# (increased)
#
# Depth measurement #36
# 330 --> 332
# (increased)
#
# Depth measurement #37
# 332 --> 337
# (increased)
#
# Depth measurement #38
# 337 --> 340
# (increased)
#
# Depth measurement #39
# 340 --> 341
# (increased)
#
# Depth measurement #40
# 341 --> 339
# (decreased)
#
# Depth measurement #41
# 339 --> 348
# (increased)
#
# Depth measurement #42
# 348 --> 349
# (increased)
#
# Depth measurement #43
# 349 --> 350
# (increased)
#
# Depth measurement #44
# 350 --> 351
# (increased)
#
# Depth measurement #45
# 351 --> 354
# (increased)
#
# Depth measurement #46
# 354 --> 357
# (increased)
#
# Depth measurement #47
# 357 --> 359
# (increased)
#
# Depth measurement #48
# 359 --> 360
# (increased)
#
# Depth measurement #49
# 360 --> 361
# (increased)
#
# Depth measurement #50
# 361 --> 363
# (increased)
#
# Depth measurement #51
# 363 --> 364
# (increased)
#
# Depth measurement #52
# 364 --> 365
# (increased)
#
# Depth measurement #53
# 365 --> 372
# (increased)
#
# Depth measurement #54
# 372 --> 373
# (increased)
#
# Depth measurement #55
# 373 --> 371
# (decreased)
#
# Depth measurement #56
# 371 --> 374
# (increased)
#
# Depth measurement #57
# 374 --> 375
# (increased)
#
# Depth measurement #58
# 375 --> 379
# (increased)
#
# Depth measurement #59
# 379 --> 383
# (increased)
#
# Depth measurement #60
# 383 --> 384
# (increased)
#
# Depth measurement #61
# 384 --> 383
# (decreased)
#
# Depth measurement #62
# 383 --> 388
# (increased)
#
# Depth measurement #63
# 388 --> 390
# (increased)
#
# Depth measurement #64
# 390 --> 395
# (increased)
#
# Depth measurement #65
# 395 --> 397
# (increased)
#
# Depth measurement #66
# 397 --> 410
# (increased)
#
# Depth measurement #67
# 410 --> 412
# (increased)
#
# Depth measurement #68
# 412 --> 411
# (decreased)
#
# Depth measurement #69
# 411 --> 414
# (increased)
#
# Depth measurement #70
# 414 --> 411
# (decreased)
#
# Depth measurement #71
# 411 --> 432
# (increased)
#
# Depth measurement #72
# 432 --> 426
# (decreased)
#
# Depth measurement #73
# 426 --> 429
# (increased)
#
# Depth measurement #74
# 429 --> 437
# (increased)
#
# Depth measurement #75
# 437 --> 438
# (increased)
#
# Depth measurement #76
# 438 --> 462
# (increased)
#
# Depth measurement #77
# 462 --> 463
# (increased)
#
# Depth measurement #78
# 463 --> 464
# (increased)
#
# Depth measurement #79
# 464 --> 477
# (increased)
#
# Depth measurement #80
# 477 --> 480
# (increased)
#
# Depth measurement #81
# 480 --> 497
# (increased)
#
# Depth measurement #82
# 497 --> 516
# (increased)
#
# Depth measurement #83
# 516 --> 524
# (increased)
#
# Depth measurement #84
# 524 --> 536
# (increased)
#
# Depth measurement #85
# 536 --> 547
# (increased)
#
# Depth measurement #86
# 547 --> 550
# (increased)
#
# Depth measurement #87
# 550 --> 555
# (increased)
#
# Depth measurement #88
# 555 --> 557
# (increased)
#
# Depth measurement #89
# 557 --> 556
# (decreased)
#
# Depth measurement #90
# 556 --> 565
# (increased)
#
# Depth measurement #91
# 565 --> 566
# (increased)
#
# Depth measurement #92
# 566 --> 567
# (increased)
#
# Depth measurement #93
# 567 --> 574
# (increased)
#
# Depth measurement #94
# 574 --> 575
# (increased)
#
# Depth measurement #95
# 575 --> 583
# (increased)
#
# Depth measurement #96
# 583 --> 585
# (increased)
#
# Depth measurement #97
# 585 --> 594
# (increased)
#
# Depth measurement #98
# 594 --> 596
# (increased)
#
# Depth measurement #99
# 596 --> 617
# (increased)
#
# Depth measurement #100
# 617 --> 621
# (increased)
#
# Depth measurement #101
# 621 --> 616
# (decreased)
#
# Depth measurement #102
# 616 --> 613
# (decreased)
#
# Depth measurement #103
# 613 --> 616
# (increased)
#
# Depth measurement #104
# 616 --> 618
# (increased)
#
# Depth measurement #105
# 618 --> 614
# (decreased)
#
# Depth measurement #106
# 614 --> 615
# (increased)
#
# Depth measurement #107
# 615 --> 618
# (increased)
#
# Depth measurement #108
# 618 --> 619
# (increased)
#
# Depth measurement #109
# 619 --> 621
# (increased)
#
# Depth measurement #110
# 621 --> 616
# (decreased)
#
# Depth measurement #111
# 616 --> 644
# (increased)
#
# Depth measurement #112
# 644 --> 649
# (increased)
#
# Depth measurement #113
# 649 --> 650
# (increased)
#
# Depth measurement #114
# 650 --> 655
# (increased)
#
# Depth measurement #115
# 655 --> 658
# (increased)
#
# Depth measurement #116
# 658 --> 657
# (decreased)
#
# Depth measurement #117
# 657 --> 658
# (increased)
#
# Depth measurement #118
# 658 --> 661
# (increased)
#
# Depth measurement #119
# 661 --> 668
# (increased)
#
# Depth measurement #120
# 668 --> 647
# (decreased)
#
# Depth measurement #121
# 647 --> 651
# (increased)
#
# Depth measurement #122
# 651 --> 657
# (increased)
#
# Depth measurement #123
# 657 --> 654
# (decreased)
#
# Depth measurement #124
# 654 --> 656
# (increased)
#
# Depth measurement #125
# 656 --> 657
# (increased)
#
# Depth measurement #126
# 657 --> 658
# (increased)
#
# Depth measurement #127
# 658 --> 666
# (increased)
#
# Depth measurement #128
# 666 --> 676
# (increased)
#
# Depth measurement #129
# 676 --> 686
# (increased)
#
# Depth measurement #130
# 686 --> 692
# (increased)
#
# Depth measurement #131
# 692 --> 701
# (increased)
#
# Depth measurement #132
# 701 --> 706
# (increased)
#
# Depth measurement #133
# 706 --> 705
# (decreased)
#
# Depth measurement #134
# 705 --> 706
# (increased)
#
# Depth measurement #135
# 706 --> 697
# (decreased)
#
# Depth measurement #136
# 697 --> 701
# (increased)
#
# Depth measurement #137
# 701 --> 670
# (decreased)
#
# Depth measurement #138
# 670 --> 663
# (decreased)
#
# Depth measurement #139
# 663 --> 667
# (increased)
#
# Depth measurement #140
# 667 --> 668
# (increased)
#
# Depth measurement #141
# 668 --> 676
# (increased)
#
# Depth measurement #142
# 676 --> 677
# (increased)
#
# Depth measurement #143
# 677 --> 676
# (decreased)
#
# Depth measurement #144
# 676 --> 692
# (increased)
#
# Depth measurement #145
# 692 --> 714
# (increased)
#
# Depth measurement #146
# 714 --> 715
# (increased)
#
# Depth measurement #147
# 715 --> 734
# (increased)
#
# Depth measurement #148
# 734 --> 768
# (increased)
#
# Depth measurement #149
# 768 --> 785
# (increased)
#
# Depth measurement #150
# 785 --> 824
# (increased)
#
# Depth measurement #151
# 824 --> 829
# (increased)
#
# Depth measurement #152
# 829 --> 845
# (increased)
#
# Depth measurement #153
# 845 --> 844
# (decreased)
#
# Depth measurement #154
# 844 --> 847
# (increased)
#
# Depth measurement #155
# 847 --> 860
# (increased)
#
# Depth measurement #156
# 860 --> 865
# (increased)
#
# Depth measurement #157
# 865 --> 880
# (increased)
#
# Depth measurement #158
# 880 --> 893
# (increased)
#
# Depth measurement #159
# 893 --> 895
# (increased)
#
# Depth measurement #160
# 895 --> 899
# (increased)
#
# Depth measurement #161
# 899 --> 900
# (increased)
#
# Depth measurement #162
# 900 --> 902
# (increased)
#
# Depth measurement #163
# 902 --> 905
# (increased)
#
# Depth measurement #164
# 905 --> 906
# (increased)
#
# Depth measurement #165
# 906 --> 907
# (increased)
#
# Depth measurement #166
# 907 --> 906
# (decreased)
#
# Depth measurement #167
# 906 --> 902
# (decreased)
#
# Depth measurement #168
# 902 --> 912
# (increased)
#
# Depth measurement #169
# 912 --> 927
# (increased)
#
# Depth measurement #170
# 927 --> 928
# (increased)
#
# Depth measurement #171
# 928 --> 945
# (increased)
#
# Depth measurement #172
# 945 --> 952
# (increased)
#
# Depth measurement #173
# 952 --> 953
# (increased)
#
# Depth measurement #174
# 953 --> 961
# (increased)
#
# Depth measurement #175
# 961 --> 969
# (increased)
#
# Depth measurement #176
# 969 --> 970
# (increased)
#
# Depth measurement #177
# 970 --> 974
# (increased)
#
# Depth measurement #178
# 974 --> 975
# (increased)
#
# Depth measurement #179
# 975 --> 976
# (increased)
#
# Depth measurement #180
# 976 --> 980
# (increased)
#
# Depth measurement #181
# 980 --> 989
# (increased)
#
# Depth measurement #182
# 989 --> 990
# (increased)
#
# Depth measurement #183
# 990 --> 993
# (increased)
#
# Depth measurement #184
# 993 --> 1006
# (increased)
#
# Depth measurement #185
# 1006 --> 1008
# (increased)
#
# Depth measurement #186
# 1008 --> 1009
# (increased)
#
# Depth measurement #187
# 1009 --> 1010
# (increased)
#
# Depth measurement #188
# 1010 --> 1012
# (increased)
#
# Depth measurement #189
# 1012 --> 1013
# (increased)
#
# Depth measurement #190
# 1013 --> 1014
# (increased)
#
# Depth measurement #191
# 1014 --> 1017
# (increased)
#
# Depth measurement #192
# 1017 --> 1024
# (increased)
#
# Depth measurement #193
# 1024 --> 1038
# (increased)
#
# Depth measurement #194
# 1038 --> 1058
# (increased)
#
# Depth measurement #195
# 1058 --> 1059
# (increased)
#
# Depth measurement #196
# 1059 --> 1065
# (increased)
#
# Depth measurement #197
# 1065 --> 1066
# (increased)
#
# Depth measurement #198
# 1066 --> 1070
# (increased)
#
# Depth measurement #199
# 1070 --> 1083
# (increased)
#
# Depth measurement #200
# 1083 --> 1085
# (increased)
#
# Depth measurement #201
# 1085 --> 1086
# (increased)
#
# Depth measurement #202
# 1086 --> 1094
# (increased)
#
# Depth measurement #203
# 1094 --> 1097
# (increased)
#
# Depth measurement #204
# 1097 --> 1102
# (increased)
#
# Depth measurement #205
# 1102 --> 1121
# (increased)
#
# Depth measurement #206
# 1121 --> 1122
# (increased)
#
# Depth measurement #207
# 1122 --> 1137
# (increased)
#
# Depth measurement #208
# 1137 --> 1138
# (increased)
#
# Depth measurement #209
# 1138 --> 1145
# (increased)
#
# Depth measurement #210
# 1145 --> 1148
# (increased)
#
# Depth measurement #211
# 1148 --> 1159
# (increased)
#
# Depth measurement #212
# 1159 --> 1170
# (increased)
#
# Depth measurement #213
# 1170 --> 1171
# (increased)
#
# Depth measurement #214
# 1171 --> 1172
# (increased)
#
# Depth measurement #215
# 1172 --> 1179
# (increased)
#
# Depth measurement #216
# 1179 --> 1175
# (decreased)
#
# Depth measurement #217
# 1175 --> 1179
# (increased)
#
# Depth measurement #218
# 1179 --> 1178
# (decreased)
#
# Depth measurement #219
# 1178 --> 1190
# (increased)
#
# Depth measurement #220
# 1190 --> 1196
# (increased)
#
# Depth measurement #221
# 1196 --> 1215
# (increased)
#
# Depth measurement #222
# 1215 --> 1220
# (increased)
#
# Depth measurement #223
# 1220 --> 1209
# (decreased)
#
# Depth measurement #224
# 1209 --> 1213
# (increased)
#
# Depth measurement #225
# 1213 --> 1214
# (increased)
#
# Depth measurement #226
# 1214 --> 1209
# (decreased)
#
# Depth measurement #227
# 1209 --> 1211
# (increased)
#
# Depth measurement #228
# 1211 --> 1251
# (increased)
#
# Depth measurement #229
# 1251 --> 1255
# (increased)
#
# Depth measurement #230
# 1255 --> 1269
# (increased)
#
# Depth measurement #231
# 1269 --> 1272
# (increased)
#
# Depth measurement #232
# 1272 --> 1273
# (increased)
#
# Depth measurement #233
# 1273 --> 1284
# (increased)
#
# Depth measurement #234
# 1284 --> 1286
# (increased)
#
# Depth measurement #235
# 1286 --> 1312
# (increased)
#
# Depth measurement #236
# 1312 --> 1314
# (increased)
#
# Depth measurement #237
# 1314 --> 1317
# (increased)
#
# Depth measurement #238
# 1317 --> 1321
# (increased)
#
# Depth measurement #239
# 1321 --> 1341
# (increased)
#
# Depth measurement #240
# 1341 --> 1357
# (increased)
#
# Depth measurement #241
# 1357 --> 1365
# (increased)
#
# Depth measurement #242
# 1365 --> 1366
# (increased)
#
# Depth measurement #243
# 1366 --> 1369
# (increased)
#
# Depth measurement #244
# 1369 --> 1379
# (increased)
#
# Depth measurement #245
# 1379 --> 1359
# (decreased)
#
# Depth measurement #246
# 1359 --> 1332
# (decreased)
#
# Depth measurement #247
# 1332 --> 1342
# (increased)
#
# Depth measurement #248
# 1342 --> 1362
# (increased)
#
# Depth measurement #249
# 1362 --> 1365
# (increased)
#
# Depth measurement #250
# 1365 --> 1375
# (increased)
#
# Depth measurement #251
# 1375 --> 1378
# (increased)
#
# Depth measurement #252
# 1378 --> 1379
# (increased)
#
# Depth measurement #253
# 1379 --> 1381
# (increased)
#
# Depth measurement #254
# 1381 --> 1387
# (increased)
#
# Depth measurement #255
# 1387 --> 1397
# (increased)
#
# Depth measurement #256
# 1397 --> 1401
# (increased)
#
# Depth measurement #257
# 1401 --> 1400
# (decreased)
#
# Depth measurement #258
# 1400 --> 1401
# (increased)
#
# Depth measurement #259
# 1401 --> 1429
# (increased)
#
# Depth measurement #260
# 1429 --> 1453
# (increased)
#
# Depth measurement #261
# 1453 --> 1454
# (increased)
#
# Depth measurement #262
# 1454 --> 1455
# (increased)
#
# Depth measurement #263
# 1455 --> 1461
# (increased)
#
# Depth measurement #264
# 1461 --> 1466
# (increased)
#
# Depth measurement #265
# 1466 --> 1467
# (increased)
#
# Depth measurement #266
# 1467 --> 1463
# (decreased)
#
# Depth measurement #267
# 1463 --> 1475
# (increased)
#
# Depth measurement #268
# 1475 --> 1489
# (increased)
#
# Depth measurement #269
# 1489 --> 1488
# (decreased)
#
# Depth measurement #270
# 1488 --> 1496
# (increased)
#
# Depth measurement #271
# 1496 --> 1506
# (increased)
#
# Depth measurement #272
# 1506 --> 1515
# (increased)
#
# Depth measurement #273
# 1515 --> 1538
# (increased)
#
# Depth measurement #274
# 1538 --> 1545
# (increased)
#
# Depth measurement #275
# 1545 --> 1538
# (decreased)
#
# Depth measurement #276
# 1538 --> 1544
# (increased)
#
# Depth measurement #277
# 1544 --> 1553
# (increased)
#
# Depth measurement #278
# 1553 --> 1555
# (increased)
#
# Depth measurement #279
# 1555 --> 1558
# (increased)
#
# Depth measurement #280
# 1558 --> 1567
# (increased)
#
# Depth measurement #281
# 1567 --> 1573
# (increased)
#
# Depth measurement #282
# 1573 --> 1577
# (increased)
#
# Depth measurement #283
# 1577 --> 1582
# (increased)
#
# Depth measurement #284
# 1582 --> 1583
# (increased)
#
# Depth measurement #285
# 1583 --> 1585
# (increased)
#
# Depth measurement #286
# 1585 --> 1586
# (increased)
#
# Depth measurement #287
# 1586 --> 1585
# (decreased)
#
# Depth measurement #288
# 1585 --> 1586
# (increased)
#
# Depth measurement #289
# 1586 --> 1601
# (increased)
#
# Depth measurement #290
# 1601 --> 1613
# (increased)
#
# Depth measurement #291
# 1613 --> 1612
# (decreased)
#
# Depth measurement #292
# 1612 --> 1630
# (increased)
#
# Depth measurement #293
# 1630 --> 1632
# (increased)
#
# Depth measurement #294
# 1632 --> 1631
# (decreased)
#
# Depth measurement #295
# 1631 --> 1638
# (increased)
#
# Depth measurement #296
# 1638 --> 1642
# (increased)
#
# Depth measurement #297
# 1642 --> 1655
# (increased)
#
# Depth measurement #298
# 1655 --> 1656
# (increased)
#
# Depth measurement #299
# 1656 --> 1613
# (decreased)
#
# Depth measurement #300
# 1613 --> 1615
# (increased)
#
# Depth measurement #301
# 1615 --> 1620
# (increased)
#
# Depth measurement #302
# 1620 --> 1611
# (decreased)
#
# Depth measurement #303
# 1611 --> 1609
# (decreased)
#
# Depth measurement #304
# 1609 --> 1615
# (increased)
#
# Depth measurement #305
# 1615 --> 1617
# (increased)
#
# Depth measurement #306
# 1617 --> 1621
# (increased)
#
# Depth measurement #307
# 1621 --> 1624
# (increased)
#
# Depth measurement #308
# 1624 --> 1634
# (increased)
#
# Depth measurement #309
# 1634 --> 1639
# (increased)
#
# Depth measurement #310
# 1639 --> 1644
# (increased)
#
# Depth measurement #311
# 1644 --> 1655
# (increased)
#
# Depth measurement #312
# 1655 --> 1678
# (increased)
#
# Depth measurement #313
# 1678 --> 1681
# (increased)
#
# Depth measurement #314
# 1681 --> 1683
# (increased)
#
# Depth measurement #315
# 1683 --> 1695
# (increased)
#
# Depth measurement #316
# 1695 --> 1698
# (increased)
#
# Depth measurement #317
# 1698 --> 1708
# (increased)
#
# Depth measurement #318
# 1708 --> 1709
# (increased)
#
# Depth measurement #319
# 1709 --> 1712
# (increased)
#
# Depth measurement #320
# 1712 --> 1713
# (increased)
#
# Depth measurement #321
# 1713 --> 1717
# (increased)
#
# Depth measurement #322
# 1717 --> 1743
# (increased)
#
# Depth measurement #323
# 1743 --> 1744
# (increased)
#
# Depth measurement #324
# 1744 --> 1747
# (increased)
#
# Depth measurement #325
# 1747 --> 1781
# (increased)
#
# Depth measurement #326
# 1781 --> 1782
# (increased)
#
# Depth measurement #327
# 1782 --> 1799
# (increased)
#
# Depth measurement #328
# 1799 --> 1803
# (increased)
#
# Depth measurement #329
# 1803 --> 1804
# (increased)
#
# Depth measurement #330
# 1804 --> 1806
# (increased)
#
# Depth measurement #331
# 1806 --> 1808
# (increased)
#
# Depth measurement #332
# 1808 --> 1825
# (increased)
#
# Depth measurement #333
# 1825 --> 1830
# (increased)
#
# Depth measurement #334
# 1830 --> 1831
# (increased)
#
# Depth measurement #335
# 1831 --> 1833
# (increased)
#
# Depth measurement #336
# 1833 --> 1848
# (increased)
#
# Depth measurement #337
# 1848 --> 1849
# (increased)
#
# Depth measurement #338
# 1849 --> 1851
# (increased)
#
# Depth measurement #339
# 1851 --> 1853
# (increased)
#
# Depth measurement #340
# 1853 --> 1858
# (increased)
#
# Depth measurement #341
# 1858 --> 1857
# (decreased)
#
# Depth measurement #342
# 1857 --> 1865
# (increased)
#
# Depth measurement #343
# 1865 --> 1867
# (increased)
#
# Depth measurement #344
# 1867 --> 1886
# (increased)
#
# Depth measurement #345
# 1886 --> 1888
# (increased)
#
# Depth measurement #346
# 1888 --> 1892
# (increased)
#
# Depth measurement #347
# 1892 --> 1902
# (increased)
#
# Depth measurement #348
# 1902 --> 1923
# (increased)
#
# Depth measurement #349
# 1923 --> 1925
# (increased)
#
# Depth measurement #350
# 1925 --> 1930
# (increased)
#
# Depth measurement #351
# 1930 --> 1931
# (increased)
#
# Depth measurement #352
# 1931 --> 1910
# (decreased)
#
# Depth measurement #353
# 1910 --> 1916
# (increased)
#
# Depth measurement #354
# 1916 --> 1922
# (increased)
#
# Depth measurement #355
# 1922 --> 1924
# (increased)
#
# Depth measurement #356
# 1924 --> 1925
# (increased)
#
# Depth measurement #357
# 1925 --> 1930
# (increased)
#
# Depth measurement #358
# 1930 --> 1918
# (decreased)
#
# Depth measurement #359
# 1918 --> 1925
# (increased)
#
# Depth measurement #360
# 1925 --> 1926
# (increased)
#
# Depth measurement #361
# 1926 --> 1929
# (increased)
#
# Depth measurement #362
# 1929 --> 1934
# (increased)
#
# Depth measurement #363
# 1934 --> 1932
# (decreased)
#
# Depth measurement #364
# 1932 --> 1926
# (decreased)
#
# Depth measurement #365
# 1926 --> 1932
# (increased)
#
# Depth measurement #366
# 1932 --> 1931
# (decreased)
#
# Depth measurement #367
# 1931 --> 1950
# (increased)
#
# Depth measurement #368
# 1950 --> 1952
# (increased)
#
# Depth measurement #369
# 1952 --> 1953
# (increased)
#
# Depth measurement #370
# 1953 --> 1964
# (increased)
#
# Depth measurement #371
# 1964 --> 1965
# (increased)
#
# Depth measurement #372
# 1965 --> 1967
# (increased)
#
# Depth measurement #373
# 1967 --> 1977
# (increased)
#
# Depth measurement #374
# 1977 --> 1979
# (increased)
#
# Depth measurement #375
# 1979 --> 1983
# (increased)
#
# Depth measurement #376
# 1983 --> 1993
# (increased)
#
# Depth measurement #377
# 1993 --> 1994
# (increased)
#
# Depth measurement #378
# 1994 --> 1996
# (increased)
#
# Depth measurement #379
# 1996 --> 2005
# (increased)
#
# Depth measurement #380
# 2005 --> 2020
# (increased)
#
# Depth measurement #381
# 2020 --> 2032
# (increased)
#
# Depth measurement #382
# 2032 --> 2033
# (increased)
#
# Depth measurement #383
# 2033 --> 2039
# (increased)
#
# Depth measurement #384
# 2039 --> 2040
# (increased)
#
# Depth measurement #385
# 2040 --> 2041
# (increased)
#
# Depth measurement #386
# 2041 --> 2045
# (increased)
#
# Depth measurement #387
# 2045 --> 2058
# (increased)
#
# Depth measurement #388
# 2058 --> 2059
# (increased)
#
# Depth measurement #389
# 2059 --> 2061
# (increased)
#
# Depth measurement #390
# 2061 --> 2063
# (increased)
#
# Depth measurement #391
# 2063 --> 2086
# (increased)
#
# Depth measurement #392
# 2086 --> 2089
# (increased)
#
# Depth measurement #393
# 2089 --> 2097
# (increased)
#
# Depth measurement #394
# 2097 --> 2095
# (decreased)
#
# Depth measurement #395
# 2095 --> 2101
# (increased)
#
# Depth measurement #396
# 2101 --> 2102
# (increased)
#
# Depth measurement #397
# 2102 --> 2105
# (increased)
#
# Depth measurement #398
# 2105 --> 2106
# (increased)
#
# Depth measurement #399
# 2106 --> 2100
# (decreased)
#
# Depth measurement #400
# 2100 --> 2113
# (increased)
#
# Depth measurement #401
# 2113 --> 2158
# (increased)
#
# Depth measurement #402
# 2158 --> 2160
# (increased)
#
# Depth measurement #403
# 2160 --> 2162
# (increased)
#
# Depth measurement #404
# 2162 --> 2164
# (increased)
#
# Depth measurement #405
# 2164 --> 2165
# (increased)
#
# Depth measurement #406
# 2165 --> 2172
# (increased)
#
# Depth measurement #407
# 2172 --> 2174
# (increased)
#
# Depth measurement #408
# 2174 --> 2176
# (increased)
#
# Depth measurement #409
# 2176 --> 2183
# (increased)
#
# Depth measurement #410
# 2183 --> 2184
# (increased)
#
# Depth measurement #411
# 2184 --> 2190
# (increased)
#
# Depth measurement #412
# 2190 --> 2189
# (decreased)
#
# Depth measurement #413
# 2189 --> 2212
# (increased)
#
# Depth measurement #414
# 2212 --> 2225
# (increased)
#
# Depth measurement #415
# 2225 --> 2233
# (increased)
#
# Depth measurement #416
# 2233 --> 2192
# (decreased)
#
# Depth measurement #417
# 2192 --> 2194
# (increased)
#
# Depth measurement #418
# 2194 --> 2215
# (increased)
#
# Depth measurement #419
# 2215 --> 2222
# (increased)
#
# Depth measurement #420
# 2222 --> 2223
# (increased)
#
# Depth measurement #421
# 2223 --> 2233
# (increased)
#
# Depth measurement #422
# 2233 --> 2241
# (increased)
#
# Depth measurement #423
# 2241 --> 2243
# (increased)
#
# Depth measurement #424
# 2243 --> 2235
# (decreased)
#
# Depth measurement #425
# 2235 --> 2246
# (increased)
#
# Depth measurement #426
# 2246 --> 2287
# (increased)
#
# Depth measurement #427
# 2287 --> 2292
# (increased)
#
# Depth measurement #428
# 2292 --> 2297
# (increased)
#
# Depth measurement #429
# 2297 --> 2298
# (increased)
#
# Depth measurement #430
# 2298 --> 2299
# (increased)
#
# Depth measurement #431
# 2299 --> 2300
# (increased)
#
# Depth measurement #432
# 2300 --> 2306
# (increased)
#
# Depth measurement #433
# 2306 --> 2308
# (increased)
#
# Depth measurement #434
# 2308 --> 2318
# (increased)
#
# Depth measurement #435
# 2318 --> 2322
# (increased)
#
# Depth measurement #436
# 2322 --> 2333
# (increased)
#
# Depth measurement #437
# 2333 --> 2332
# (decreased)
#
# Depth measurement #438
# 2332 --> 2312
# (decreased)
#
# Depth measurement #439
# 2312 --> 2309
# (decreased)
#
# Depth measurement #440
# 2309 --> 2313
# (increased)
#
# Depth measurement #441
# 2313 --> 2297
# (decreased)
#
# Depth measurement #442
# 2297 --> 2306
# (increased)
#
# Depth measurement #443
# 2306 --> 2323
# (increased)
#
# Depth measurement #444
# 2323 --> 2336
# (increased)
#
# Depth measurement #445
# 2336 --> 2339
# (increased)
#
# Depth measurement #446
# 2339 --> 2322
# (decreased)
#
# Depth measurement #447
# 2322 --> 2323
# (increased)
#
# Depth measurement #448
# 2323 --> 2327
# (increased)
#
# Depth measurement #449
# 2327 --> 2332
# (increased)
#
# Depth measurement #450
# 2332 --> 2351
# (increased)
#
# Depth measurement #451
# 2351 --> 2361
# (increased)
#
# Depth measurement #452
# 2361 --> 2363
# (increased)
#
# Depth measurement #453
# 2363 --> 2364
# (increased)
#
# Depth measurement #454
# 2364 --> 2365
# (increased)
#
# Depth measurement #455
# 2365 --> 2371
# (increased)
#
# Depth measurement #456
# 2371 --> 2395
# (increased)
#
# Depth measurement #457
# 2395 --> 2393
# (decreased)
#
# Depth measurement #458
# 2393 --> 2394
# (increased)
#
# Depth measurement #459
# 2394 --> 2423
# (increased)
#
# Depth measurement #460
# 2423 --> 2435
# (increased)
#
# Depth measurement #461
# 2435 --> 2438
# (increased)
#
# Depth measurement #462
# 2438 --> 2443
# (increased)
#
# Depth measurement #463
# 2443 --> 2444
# (increased)
#
# Depth measurement #464
# 2444 --> 2450
# (increased)
#
# Depth measurement #465
# 2450 --> 2449
# (decreased)
#
# Depth measurement #466
# 2449 --> 2453
# (increased)
#
# Depth measurement #467
# 2453 --> 2456
# (increased)
#
# Depth measurement #468
# 2456 --> 2457
# (increased)
#
# Depth measurement #469
# 2457 --> 2456
# (decreased)
#
# Depth measurement #470
# 2456 --> 2462
# (increased)
#
# Depth measurement #471
# 2462 --> 2463
# (increased)
#
# Depth measurement #472
# 2463 --> 2477
# (increased)
#
# Depth measurement #473
# 2477 --> 2478
# (increased)
#
# Depth measurement #474
# 2478 --> 2484
# (increased)
#
# Depth measurement #475
# 2484 --> 2485
# (increased)
#
# Depth measurement #476
# 2485 --> 2498
# (increased)
#
# Depth measurement #477
# 2498 --> 2499
# (increased)
#
# Depth measurement #478
# 2499 --> 2497
# (decreased)
#
# Depth measurement #479
# 2497 --> 2498
# (increased)
#
# Depth measurement #480
# 2498 --> 2499
# (increased)
#
# Depth measurement #481
# 2499 --> 2501
# (increased)
#
# Depth measurement #482
# 2501 --> 2502
# (increased)
#
# Depth measurement #483
# 2502 --> 2505
# (increased)
#
# Depth measurement #484
# 2505 --> 2518
# (increased)
#
# Depth measurement #485
# 2518 --> 2521
# (increased)
#
# Depth measurement #486
# 2521 --> 2522
# (increased)
#
# Depth measurement #487
# 2522 --> 2520
# (decreased)
#
# Depth measurement #488
# 2520 --> 2521
# (increased)
#
# Depth measurement #489
# 2521 --> 2523
# (increased)
#
# Depth measurement #490
# 2523 --> 2529
# (increased)
#
# Depth measurement #491
# 2529 --> 2530
# (increased)
#
# Depth measurement #492
# 2530 --> 2528
# (decreased)
#
# Depth measurement #493
# 2528 --> 2544
# (increased)
#
# Depth measurement #494
# 2544 --> 2545
# (increased)
#
# Depth measurement #495
# 2545 --> 2546
# (increased)
#
# Depth measurement #496
# 2546 --> 2547
# (increased)
#
# Depth measurement #497
# 2547 --> 2590
# (increased)
#
# Depth measurement #498
# 2590 --> 2612
# (increased)
#
# Depth measurement #499
# 2612 --> 2620
# (increased)
#
# Depth measurement #500
# 2620 --> 2631
# (increased)
#
# Depth measurement #501
# 2631 --> 2634
# (increased)
#
# Depth measurement #502
# 2634 --> 2633
# (decreased)
#
# Depth measurement #503
# 2633 --> 2634
# (increased)
#
# Depth measurement #504
# 2634 --> 2635
# (increased)
#
# Depth measurement #505
# 2635 --> 2661
# (increased)
#
# Depth measurement #506
# 2661 --> 2663
# (increased)
#
# Depth measurement #507
# 2663 --> 2667
# (increased)
#
# Depth measurement #508
# 2667 --> 2670
# (increased)
#
# Depth measurement #509
# 2670 --> 2676
# (increased)
#
# Depth measurement #510
# 2676 --> 2678
# (increased)
#
# Depth measurement #511
# 2678 --> 2654
# (decreased)
#
# Depth measurement #512
# 2654 --> 2664
# (increased)
#
# Depth measurement #513
# 2664 --> 2665
# (increased)
#
# Depth measurement #514
# 2665 --> 2671
# (increased)
#
# Depth measurement #515
# 2671 --> 2681
# (increased)
#
# Depth measurement #516
# 2681 --> 2684
# (increased)
#
# Depth measurement #517
# 2684 --> 2711
# (increased)
#
# Depth measurement #518
# 2711 --> 2725
# (increased)
#
# Depth measurement #519
# 2725 --> 2726
# (increased)
#
# Depth measurement #520
# 2726 --> 2728
# (increased)
#
# Depth measurement #521
# 2728 --> 2729
# (increased)
#
# Depth measurement #522
# 2729 --> 2734
# (increased)
#
# Depth measurement #523
# 2734 --> 2735
# (increased)
#
# Depth measurement #524
# 2735 --> 2740
# (increased)
#
# Depth measurement #525
# 2740 --> 2759
# (increased)
#
# Depth measurement #526
# 2759 --> 2758
# (decreased)
#
# Depth measurement #527
# 2758 --> 2762
# (increased)
#
# Depth measurement #528
# 2762 --> 2763
# (increased)
#
# Depth measurement #529
# 2763 --> 2765
# (increased)
#
# Depth measurement #530
# 2765 --> 2768
# (increased)
#
# Depth measurement #531
# 2768 --> 2749
# (decreased)
#
# Depth measurement #532
# 2749 --> 2750
# (increased)
#
# Depth measurement #533
# 2750 --> 2752
# (increased)
#
# Depth measurement #534
# 2752 --> 2758
# (increased)
#
# Depth measurement #535
# 2758 --> 2728
# (decreased)
#
# Depth measurement #536
# 2728 --> 2732
# (increased)
#
# Depth measurement #537
# 2732 --> 2749
# (increased)
#
# Depth measurement #538
# 2749 --> 2748
# (decreased)
#
# Depth measurement #539
# 2748 --> 2763
# (increased)
#
# Depth measurement #540
# 2763 --> 2766
# (increased)
#
# Depth measurement #541
# 2766 --> 2767
# (increased)
#
# Depth measurement #542
# 2767 --> 2769
# (increased)
#
# Depth measurement #543
# 2769 --> 2764
# (decreased)
#
# Depth measurement #544
# 2764 --> 2765
# (increased)
#
# Depth measurement #545
# 2765 --> 2768
# (increased)
#
# Depth measurement #546
# 2768 --> 2769
# (increased)
#
# Depth measurement #547
# 2769 --> 2772
# (increased)
#
# Depth measurement #548
# 2772 --> 2758
# (decreased)
#
# Depth measurement #549
# 2758 --> 2777
# (increased)
#
# Depth measurement #550
# 2777 --> 2788
# (increased)
#
# Depth measurement #551
# 2788 --> 2811
# (increased)
#
# Depth measurement #552
# 2811 --> 2815
# (increased)
#
# Depth measurement #553
# 2815 --> 2820
# (increased)
#
# Depth measurement #554
# 2820 --> 2824
# (increased)
#
# Depth measurement #555
# 2824 --> 2832
# (increased)
#
# Depth measurement #556
# 2832 --> 2839
# (increased)
#
# Depth measurement #557
# 2839 --> 2841
# (increased)
#
# Depth measurement #558
# 2841 --> 2839
# (decreased)
#
# Depth measurement #559
# 2839 --> 2840
# (increased)
#
# Depth measurement #560
# 2840 --> 2869
# (increased)
#
# Depth measurement #561
# 2869 --> 2872
# (increased)
#
# Depth measurement #562
# 2872 --> 2847
# (decreased)
#
# Depth measurement #563
# 2847 --> 2857
# (increased)
#
# Depth measurement #564
# 2857 --> 2858
# (increased)
#
# Depth measurement #565
# 2858 --> 2860
# (increased)
#
# Depth measurement #566
# 2860 --> 2865
# (increased)
#
# Depth measurement #567
# 2865 --> 2855
# (decreased)
#
# Depth measurement #568
# 2855 --> 2851
# (decreased)
#
# Depth measurement #569
# 2851 --> 2866
# (increased)
#
# Depth measurement #570
# 2866 --> 2870
# (increased)
#
# Depth measurement #571
# 2870 --> 2871
# (increased)
#
# Depth measurement #572
# 2871 --> 2872
# (increased)
#
# Depth measurement #573
# 2872 --> 2878
# (increased)
#
# Depth measurement #574
# 2878 --> 2894
# (increased)
#
# Depth measurement #575
# 2894 --> 2899
# (increased)
#
# Depth measurement #576
# 2899 --> 2900
# (increased)
#
# Depth measurement #577
# 2900 --> 2907
# (increased)
#
# Depth measurement #578
# 2907 --> 2913
# (increased)
#
# Depth measurement #579
# 2913 --> 2905
# (decreased)
#
# Depth measurement #580
# 2905 --> 2916
# (increased)
#
# Depth measurement #581
# 2916 --> 2917
# (increased)
#
# Depth measurement #582
# 2917 --> 2916
# (decreased)
#
# Depth measurement #583
# 2916 --> 2913
# (decreased)
#
# Depth measurement #584
# 2913 --> 2919
# (increased)
#
# Depth measurement #585
# 2919 --> 2933
# (increased)
#
# Depth measurement #586
# 2933 --> 2935
# (increased)
#
# Depth measurement #587
# 2935 --> 2940
# (increased)
#
# Depth measurement #588
# 2940 --> 2945
# (increased)
#
# Depth measurement #589
# 2945 --> 2953
# (increased)
#
# Depth measurement #590
# 2953 --> 2965
# (increased)
#
# Depth measurement #591
# 2965 --> 2976
# (increased)
#
# Depth measurement #592
# 2976 --> 2986
# (increased)
#
# Depth measurement #593
# 2986 --> 2990
# (increased)
#
# Depth measurement #594
# 2990 --> 3013
# (increased)
#
# Depth measurement #595
# 3013 --> 3017
# (increased)
#
# Depth measurement #596
# 3017 --> 3004
# (decreased)
#
# Depth measurement #597
# 3004 --> 2997
# (decreased)
#
# Depth measurement #598
# 2997 --> 2998
# (increased)
#
# Depth measurement #599
# 2998 --> 2999
# (increased)
#
# Depth measurement #600
# 2999 --> 3000
# (increased)
#
# Depth measurement #601
# 3000 --> 2995
# (decreased)
#
# Depth measurement #602
# 2995 --> 2996
# (increased)
#
# Depth measurement #603
# 2996 --> 2997
# (increased)
#
# Depth measurement #604
# 2997 --> 2998
# (increased)
#
# Depth measurement #605
# 2998 --> 3006
# (increased)
#
# Depth measurement #606
# 3006 --> 3008
# (increased)
#
# Depth measurement #607
# 3008 --> 3019
# (increased)
#
# Depth measurement #608
# 3019 --> 3022
# (increased)
#
# Depth measurement #609
# 3022 --> 3024
# (increased)
#
# Depth measurement #610
# 3024 --> 3025
# (increased)
#
# Depth measurement #611
# 3025 --> 3026
# (increased)
#
# Depth measurement #612
# 3026 --> 3027
# (increased)
#
# Depth measurement #613
# 3027 --> 3028
# (increased)
#
# Depth measurement #614
# 3028 --> 3031
# (increased)
#
# Depth measurement #615
# 3031 --> 3033
# (increased)
#
# Depth measurement #616
# 3033 --> 3038
# (increased)
#
# Depth measurement #617
# 3038 --> 3042
# (increased)
#
# Depth measurement #618
# 3042 --> 3079
# (increased)
#
# Depth measurement #619
# 3079 --> 3080
# (increased)
#
# Depth measurement #620
# 3080 --> 3087
# (increased)
#
# Depth measurement #621
# 3087 --> 3117
# (increased)
#
# Depth measurement #622
# 3117 --> 3119
# (increased)
#
# Depth measurement #623
# 3119 --> 3120
# (increased)
#
# Depth measurement #624
# 3120 --> 3121
# (increased)
#
# Depth measurement #625
# 3121 --> 3122
# (increased)
#
# Depth measurement #626
# 3122 --> 3123
# (increased)
#
# Depth measurement #627
# 3123 --> 3130
# (increased)
#
# Depth measurement #628
# 3130 --> 3135
# (increased)
#
# Depth measurement #629
# 3135 --> 3130
# (decreased)
#
# Depth measurement #630
# 3130 --> 3132
# (increased)
#
# Depth measurement #631
# 3132 --> 3134
# (increased)
#
# Depth measurement #632
# 3134 --> 3153
# (increased)
#
# Depth measurement #633
# 3153 --> 3167
# (increased)
#
# Depth measurement #634
# 3167 --> 3168
# (increased)
#
# Depth measurement #635
# 3168 --> 3173
# (increased)
#
# Depth measurement #636
# 3173 --> 3178
# (increased)
#
# Depth measurement #637
# 3178 --> 3180
# (increased)
#
# Depth measurement #638
# 3180 --> 3189
# (increased)
#
# Depth measurement #639
# 3189 --> 3190
# (increased)
#
# Depth measurement #640
# 3190 --> 3209
# (increased)
#
# Depth measurement #641
# 3209 --> 3242
# (increased)
#
# Depth measurement #642
# 3242 --> 3246
# (increased)
#
# Depth measurement #643
# 3246 --> 3259
# (increased)
#
# Depth measurement #644
# 3259 --> 3265
# (increased)
#
# Depth measurement #645
# 3265 --> 3269
# (increased)
#
# Depth measurement #646
# 3269 --> 3275
# (increased)
#
# Depth measurement #647
# 3275 --> 3279
# (increased)
#
# Depth measurement #648
# 3279 --> 3285
# (increased)
#
# Depth measurement #649
# 3285 --> 3301
# (increased)
#
# Depth measurement #650
# 3301 --> 3318
# (increased)
#
# Depth measurement #651
# 3318 --> 3315
# (decreased)
#
# Depth measurement #652
# 3315 --> 3324
# (increased)
#
# Depth measurement #653
# 3324 --> 3328
# (increased)
#
# Depth measurement #654
# 3328 --> 3330
# (increased)
#
# Depth measurement #655
# 3330 --> 3352
# (increased)
#
# Depth measurement #656
# 3352 --> 3354
# (increased)
#
# Depth measurement #657
# 3354 --> 3351
# (decreased)
#
# Depth measurement #658
# 3351 --> 3358
# (increased)
#
# Depth measurement #659
# 3358 --> 3392
# (increased)
#
# Depth measurement #660
# 3392 --> 3393
# (increased)
#
# Depth measurement #661
# 3393 --> 3416
# (increased)
#
# Depth measurement #662
# 3416 --> 3417
# (increased)
#
# Depth measurement #663
# 3417 --> 3421
# (increased)
#
# Depth measurement #664
# 3421 --> 3420
# (decreased)
#
# Depth measurement #665
# 3420 --> 3441
# (increased)
#
# Depth measurement #666
# 3441 --> 3458
# (increased)
#
# Depth measurement #667
# 3458 --> 3476
# (increased)
#
# Depth measurement #668
# 3476 --> 3481
# (increased)
#
# Depth measurement #669
# 3481 --> 3491
# (increased)
#
# Depth measurement #670
# 3491 --> 3510
# (increased)
#
# Depth measurement #671
# 3510 --> 3512
# (increased)
#
# Depth measurement #672
# 3512 --> 3515
# (increased)
#
# Depth measurement #673
# 3515 --> 3550
# (increased)
#
# Depth measurement #674
# 3550 --> 3551
# (increased)
#
# Depth measurement #675
# 3551 --> 3555
# (increased)
#
# Depth measurement #676
# 3555 --> 3557
# (increased)
#
# Depth measurement #677
# 3557 --> 3586
# (increased)
#
# Depth measurement #678
# 3586 --> 3604
# (increased)
#
# Depth measurement #679
# 3604 --> 3609
# (increased)
#
# Depth measurement #680
# 3609 --> 3616
# (increased)
#
# Depth measurement #681
# 3616 --> 3623
# (increased)
#
# Depth measurement #682
# 3623 --> 3626
# (increased)
#
# Depth measurement #683
# 3626 --> 3606
# (decreased)
#
# Depth measurement #684
# 3606 --> 3627
# (increased)
#
# Depth measurement #685
# 3627 --> 3636
# (increased)
#
# Depth measurement #686
# 3636 --> 3637
# (increased)
#
# Depth measurement #687
# 3637 --> 3640
# (increased)
#
# Depth measurement #688
# 3640 --> 3626
# (decreased)
#
# Depth measurement #689
# 3626 --> 3635
# (increased)
#
# Depth measurement #690
# 3635 --> 3644
# (increased)
#
# Depth measurement #691
# 3644 --> 3661
# (increased)
#
# Depth measurement #692
# 3661 --> 3665
# (increased)
#
# Depth measurement #693
# 3665 --> 3667
# (increased)
#
# Depth measurement #694
# 3667 --> 3665
# (decreased)
#
# Depth measurement #695
# 3665 --> 3671
# (increased)
#
# Depth measurement #696
# 3671 --> 3674
# (increased)
#
# Depth measurement #697
# 3674 --> 3684
# (increased)
#
# Depth measurement #698
# 3684 --> 3688
# (increased)
#
# Depth measurement #699
# 3688 --> 3689
# (increased)
#
# Depth measurement #700
# 3689 --> 3693
# (increased)
#
# Depth measurement #701
# 3693 --> 3720
# (increased)
#
# Depth measurement #702
# 3720 --> 3728
# (increased)
#
# Depth measurement #703
# 3728 --> 3731
# (increased)
#
# Depth measurement #704
# 3731 --> 3730
# (decreased)
#
# Depth measurement #705
# 3730 --> 3733
# (increased)
#
# Depth measurement #706
# 3733 --> 3737
# (increased)
#
# Depth measurement #707
# 3737 --> 3751
# (increased)
#
# Depth measurement #708
# 3751 --> 3753
# (increased)
#
# Depth measurement #709
# 3753 --> 3754
# (increased)
#
# Depth measurement #710
# 3754 --> 3755
# (increased)
#
# Depth measurement #711
# 3755 --> 3760
# (increased)
#
# Depth measurement #712
# 3760 --> 3762
# (increased)
#
# Depth measurement #713
# 3762 --> 3765
# (increased)
#
# Depth measurement #714
# 3765 --> 3769
# (increased)
#
# Depth measurement #715
# 3769 --> 3770
# (increased)
#
# Depth measurement #716
# 3770 --> 3769
# (decreased)
#
# Depth measurement #717
# 3769 --> 3774
# (increased)
#
# Depth measurement #718
# 3774 --> 3753
# (decreased)
#
# Depth measurement #719
# 3753 --> 3755
# (increased)
#
# Depth measurement #720
# 3755 --> 3758
# (increased)
#
# Depth measurement #721
# 3758 --> 3787
# (increased)
#
# Depth measurement #722
# 3787 --> 3801
# (increased)
#
# Depth measurement #723
# 3801 --> 3800
# (decreased)
#
# Depth measurement #724
# 3800 --> 3826
# (increased)
#
# Depth measurement #725
# 3826 --> 3840
# (increased)
#
# Depth measurement #726
# 3840 --> 3843
# (increased)
#
# Depth measurement #727
# 3843 --> 3857
# (increased)
#
# Depth measurement #728
# 3857 --> 3858
# (increased)
#
# Depth measurement #729
# 3858 --> 3859
# (increased)
#
# Depth measurement #730
# 3859 --> 3862
# (increased)
#
# Depth measurement #731
# 3862 --> 3901
# (increased)
#
# Depth measurement #732
# 3901 --> 3911
# (increased)
#
# Depth measurement #733
# 3911 --> 3913
# (increased)
#
# Depth measurement #734
# 3913 --> 3915
# (increased)
#
# Depth measurement #735
# 3915 --> 3916
# (increased)
#
# Depth measurement #736
# 3916 --> 3914
# (decreased)
#
# Depth measurement #737
# 3914 --> 3896
# (decreased)
#
# Depth measurement #738
# 3896 --> 3924
# (increased)
#
# Depth measurement #739
# 3924 --> 3925
# (increased)
#
# Depth measurement #740
# 3925 --> 3927
# (increased)
#
# Depth measurement #741
# 3927 --> 3929
# (increased)
#
# Depth measurement #742
# 3929 --> 3931
# (increased)
#
# Depth measurement #743
# 3931 --> 3935
# (increased)
#
# Depth measurement #744
# 3935 --> 3936
# (increased)
#
# Depth measurement #745
# 3936 --> 3944
# (increased)
#
# Depth measurement #746
# 3944 --> 3945
# (increased)
#
# Depth measurement #747
# 3945 --> 3943
# (decreased)
#
# Depth measurement #748
# 3943 --> 3946
# (increased)
#
# Depth measurement #749
# 3946 --> 3948
# (increased)
#
# Depth measurement #750
# 3948 --> 3949
# (increased)
#
# Depth measurement #751
# 3949 --> 3966
# (increased)
#
# Depth measurement #752
# 3966 --> 3967
# (increased)
#
# Depth measurement #753
# 3967 --> 3956
# (decreased)
#
# Depth measurement #754
# 3956 --> 3964
# (increased)
#
# Depth measurement #755
# 3964 --> 3971
# (increased)
#
# Depth measurement #756
# 3971 --> 3981
# (increased)
#
# Depth measurement #757
# 3981 --> 3988
# (increased)
#
# Depth measurement #758
# 3988 --> 3989
# (increased)
#
# Depth measurement #759
# 3989 --> 3992
# (increased)
#
# Depth measurement #760
# 3992 --> 4000
# (increased)
#
# Depth measurement #761
# 4000 --> 4007
# (increased)
#
# Depth measurement #762
# 4007 --> 4009
# (increased)
#
# Depth measurement #763
# 4009 --> 4010
# (increased)
#
# Depth measurement #764
# 4010 --> 4018
# (increased)
#
# Depth measurement #765
# 4018 --> 4019
# (increased)
#
# Depth measurement #766
# 4019 --> 4020
# (increased)
#
# Depth measurement #767
# 4020 --> 4021
# (increased)
#
# Depth measurement #768
# 4021 --> 4022
# (increased)
#
# Depth measurement #769
# 4022 --> 4037
# (increased)
#
# Depth measurement #770
# 4037 --> 4025
# (decreased)
#
# Depth measurement #771
# 4025 --> 4026
# (increased)
#
# Depth measurement #772
# 4026 --> 4024
# (decreased)
#
# Depth measurement #773
# 4024 --> 4025
# (increased)
#
# Depth measurement #774
# 4025 --> 4026
# (increased)
#
# Depth measurement #775
# 4026 --> 4025
# (decreased)
#
# Depth measurement #776
# 4025 --> 4028
# (increased)
#
# Depth measurement #777
# 4028 --> 4021
# (decreased)
#
# Depth measurement #778
# 4021 --> 4010
# (decreased)
#
# Depth measurement #779
# 4010 --> 4038
# (increased)
#
# Depth measurement #780
# 4038 --> 4039
# (increased)
#
# Depth measurement #781
# 4039 --> 4041
# (increased)
#
# Depth measurement #782
# 4041 --> 4042
# (increased)
#
# Depth measurement #783
# 4042 --> 4030
# (decreased)
#
# Depth measurement #784
# 4030 --> 4027
# (decreased)
#
# Depth measurement #785
# 4027 --> 4000
# (decreased)
#
# Depth measurement #786
# 4000 --> 4001
# (increased)
#
# Depth measurement #787
# 4001 --> 4012
# (increased)
#
# Depth measurement #788
# 4012 --> 4013
# (increased)
#
# Depth measurement #789
# 4013 --> 4021
# (increased)
#
# Depth measurement #790
# 4021 --> 4022
# (increased)
#
# Depth measurement #791
# 4022 --> 4023
# (increased)
#
# Depth measurement #792
# 4023 --> 4036
# (increased)
#
# Depth measurement #793
# 4036 --> 4037
# (increased)
#
# Depth measurement #794
# 4037 --> 4051
# (increased)
#
# Depth measurement #795
# 4051 --> 4047
# (decreased)
#
# Depth measurement #796
# 4047 --> 4054
# (increased)
#
# Depth measurement #797
# 4054 --> 4057
# (increased)
#
# Depth measurement #798
# 4057 --> 4064
# (increased)
#
# Depth measurement #799
# 4064 --> 4056
# (decreased)
#
# Depth measurement #800
# 4056 --> 4040
# (decreased)
#
# Depth measurement #801
# 4040 --> 4042
# (increased)
#
# Depth measurement #802
# 4042 --> 4045
# (increased)
#
# Depth measurement #803
# 4045 --> 4060
# (increased)
#
# Depth measurement #804
# 4060 --> 4061
# (increased)
#
# Depth measurement #805
# 4061 --> 4065
# (increased)
#
# Depth measurement #806
# 4065 --> 4066
# (increased)
#
# Depth measurement #807
# 4066 --> 4058
# (decreased)
#
# Depth measurement #808
# 4058 --> 4061
# (increased)
#
# Depth measurement #809
# 4061 --> 4058
# (decreased)
#
# Depth measurement #810
# 4058 --> 4060
# (increased)
#
# Depth measurement #811
# 4060 --> 4061
# (increased)
#
# Depth measurement #812
# 4061 --> 4065
# (increased)
#
# Depth measurement #813
# 4065 --> 4066
# (increased)
#
# Depth measurement #814
# 4066 --> 4060
# (decreased)
#
# Depth measurement #815
# 4060 --> 4062
# (increased)
#
# Depth measurement #816
# 4062 --> 4054
# (decreased)
#
# Depth measurement #817
# 4054 --> 4055
# (increased)
#
# Depth measurement #818
# 4055 --> 4056
# (increased)
#
# Depth measurement #819
# 4056 --> 4078
# (increased)
#
# Depth measurement #820
# 4078 --> 4083
# (increased)
#
# Depth measurement #821
# 4083 --> 4084
# (increased)
#
# Depth measurement #822
# 4084 --> 4098
# (increased)
#
# Depth measurement #823
# 4098 --> 4101
# (increased)
#
# Depth measurement #824
# 4101 --> 4102
# (increased)
#
# Depth measurement #825
# 4102 --> 4079
# (decreased)
#
# Depth measurement #826
# 4079 --> 4089
# (increased)
#
# Depth measurement #827
# 4089 --> 4106
# (increased)
#
# Depth measurement #828
# 4106 --> 4111
# (increased)
#
# Depth measurement #829
# 4111 --> 4112
# (increased)
#
# Depth measurement #830
# 4112 --> 4147
# (increased)
#
# Depth measurement #831
# 4147 --> 4157
# (increased)
#
# Depth measurement #832
# 4157 --> 4158
# (increased)
#
# Depth measurement #833
# 4158 --> 4165
# (increased)
#
# Depth measurement #834
# 4165 --> 4174
# (increased)
#
# Depth measurement #835
# 4174 --> 4178
# (increased)
#
# Depth measurement #836
# 4178 --> 4183
# (increased)
#
# Depth measurement #837
# 4183 --> 4184
# (increased)
#
# Depth measurement #838
# 4184 --> 4196
# (increased)
#
# Depth measurement #839
# 4196 --> 4197
# (increased)
#
# Depth measurement #840
# 4197 --> 4202
# (increased)
#
# Depth measurement #841
# 4202 --> 4200
# (decreased)
#
# Depth measurement #842
# 4200 --> 4202
# (increased)
#
# Depth measurement #843
# 4202 --> 4209
# (increased)
#
# Depth measurement #844
# 4209 --> 4221
# (increased)
#
# Depth measurement #845
# 4221 --> 4225
# (increased)
#
# Depth measurement #846
# 4225 --> 4233
# (increased)
#
# Depth measurement #847
# 4233 --> 4239
# (increased)
#
# Depth measurement #848
# 4239 --> 4240
# (increased)
#
# Depth measurement #849
# 4240 --> 4234
# (decreased)
#
# Depth measurement #850
# 4234 --> 4236
# (increased)
#
# Depth measurement #851
# 4236 --> 4249
# (increased)
#
# Depth measurement #852
# 4249 --> 4250
# (increased)
#
# Depth measurement #853
# 4250 --> 4252
# (increased)
#
# Depth measurement #854
# 4252 --> 4253
# (increased)
#
# Depth measurement #855
# 4253 --> 4254
# (increased)
#
# Depth measurement #856
# 4254 --> 4253
# (decreased)
#
# Depth measurement #857
# 4253 --> 4254
# (increased)
#
# Depth measurement #858
# 4254 --> 4267
# (increased)
#
# Depth measurement #859
# 4267 --> 4272
# (increased)
#
# Depth measurement #860
# 4272 --> 4281
# (increased)
#
# Depth measurement #861
# 4281 --> 4256
# (decreased)
#
# Depth measurement #862
# 4256 --> 4255
# (decreased)
#
# Depth measurement #863
# 4255 --> 4256
# (increased)
#
# Depth measurement #864
# 4256 --> 4258
# (increased)
#
# Depth measurement #865
# 4258 --> 4264
# (increased)
#
# Depth measurement #866
# 4264 --> 4265
# (increased)
#
# Depth measurement #867
# 4265 --> 4264
# (decreased)
#
# Depth measurement #868
# 4264 --> 4266
# (increased)
#
# Depth measurement #869
# 4266 --> 4270
# (increased)
#
# Depth measurement #870
# 4270 --> 4271
# (increased)
#
# Depth measurement #871
# 4271 --> 4273
# (increased)
#
# Depth measurement #872
# 4273 --> 4284
# (increased)
#
# Depth measurement #873
# 4284 --> 4292
# (increased)
#
# Depth measurement #874
# 4292 --> 4293
# (increased)
#
# Depth measurement #875
# 4293 --> 4292
# (decreased)
#
# Depth measurement #876
# 4292 --> 4293
# (increased)
#
# Depth measurement #877
# 4293 --> 4294
# (increased)
#
# Depth measurement #878
# 4294 --> 4295
# (increased)
#
# Depth measurement #879
# 4295 --> 4303
# (increased)
#
# Depth measurement #880
# 4303 --> 4304
# (increased)
#
# Depth measurement #881
# 4304 --> 4309
# (increased)
#
# Depth measurement #882
# 4309 --> 4310
# (increased)
#
# Depth measurement #883
# 4310 --> 4311
# (increased)
#
# Depth measurement #884
# 4311 --> 4313
# (increased)
#
# Depth measurement #885
# 4313 --> 4314
# (increased)
#
# Depth measurement #886
# 4314 --> 4317
# (increased)
#
# Depth measurement #887
# 4317 --> 4322
# (increased)
#
# Depth measurement #888
# 4322 --> 4324
# (increased)
#
# Depth measurement #889
# 4324 --> 4328
# (increased)
#
# Depth measurement #890
# 4328 --> 4322
# (decreased)
#
# Depth measurement #891
# 4322 --> 4345
# (increased)
#
# Depth measurement #892
# 4345 --> 4347
# (increased)
#
# Depth measurement #893
# 4347 --> 4354
# (increased)
#
# Depth measurement #894
# 4354 --> 4348
# (decreased)
#
# Depth measurement #895
# 4348 --> 4349
# (increased)
#
# Depth measurement #896
# 4349 --> 4352
# (increased)
#
# Depth measurement #897
# 4352 --> 4368
# (increased)
#
# Depth measurement #898
# 4368 --> 4378
# (increased)
#
# Depth measurement #899
# 4378 --> 4385
# (increased)
#
# Depth measurement #900
# 4385 --> 4391
# (increased)
#
# Depth measurement #901
# 4391 --> 4407
# (increased)
#
# Depth measurement #902
# 4407 --> 4416
# (increased)
#
# Depth measurement #903
# 4416 --> 4417
# (increased)
#
# Depth measurement #904
# 4417 --> 4436
# (increased)
#
# Depth measurement #905
# 4436 --> 4439
# (increased)
#
# Depth measurement #906
# 4439 --> 4438
# (decreased)
#
# Depth measurement #907
# 4438 --> 4427
# (decreased)
#
# Depth measurement #908
# 4427 --> 4436
# (increased)
#
# Depth measurement #909
# 4436 --> 4437
# (increased)
#
# Depth measurement #910
# 4437 --> 4451
# (increased)
#
# Depth measurement #911
# 4451 --> 4452
# (increased)
#
# Depth measurement #912
# 4452 --> 4456
# (increased)
#
# Depth measurement #913
# 4456 --> 4462
# (increased)
#
# Depth measurement #914
# 4462 --> 4464
# (increased)
#
# Depth measurement #915
# 4464 --> 4465
# (increased)
#
# Depth measurement #916
# 4465 --> 4466
# (increased)
#
# Depth measurement #917
# 4466 --> 4475
# (increased)
#
# Depth measurement #918
# 4475 --> 4486
# (increased)
#
# Depth measurement #919
# 4486 --> 4498
# (increased)
#
# Depth measurement #920
# 4498 --> 4499
# (increased)
#
# Depth measurement #921
# 4499 --> 4501
# (increased)
#
# Depth measurement #922
# 4501 --> 4502
# (increased)
#
# Depth measurement #923
# 4502 --> 4511
# (increased)
#
# Depth measurement #924
# 4511 --> 4521
# (increased)
#
# Depth measurement #925
# 4521 --> 4524
# (increased)
#
# Depth measurement #926
# 4524 --> 4525
# (increased)
#
# Depth measurement #927
# 4525 --> 4528
# (increased)
#
# Depth measurement #928
# 4528 --> 4531
# (increased)
#
# Depth measurement #929
# 4531 --> 4535
# (increased)
#
# Depth measurement #930
# 4535 --> 4540
# (increased)
#
# Depth measurement #931
# 4540 --> 4542
# (increased)
#
# Depth measurement #932
# 4542 --> 4544
# (increased)
#
# Depth measurement #933
# 4544 --> 4543
# (decreased)
#
# Depth measurement #934
# 4543 --> 4544
# (increased)
#
# Depth measurement #935
# 4544 --> 4558
# (increased)
#
# Depth measurement #936
# 4558 --> 4580
# (increased)
#
# Depth measurement #937
# 4580 --> 4581
# (increased)
#
# Depth measurement #938
# 4581 --> 4582
# (increased)
#
# Depth measurement #939
# 4582 --> 4583
# (increased)
#
# Depth measurement #940
# 4583 --> 4585
# (increased)
#
# Depth measurement #941
# 4585 --> 4596
# (increased)
#
# Depth measurement #942
# 4596 --> 4597
# (increased)
#
# Depth measurement #943
# 4597 --> 4590
# (decreased)
#
# Depth measurement #944
# 4590 --> 4597
# (increased)
#
# Depth measurement #945
# 4597 --> 4598
# (increased)
#
# Depth measurement #946
# 4598 --> 4631
# (increased)
#
# Depth measurement #947
# 4631 --> 4649
# (increased)
#
# Depth measurement #948
# 4649 --> 4650
# (increased)
#
# Depth measurement #949
# 4650 --> 4661
# (increased)
#
# Depth measurement #950
# 4661 --> 4662
# (increased)
#
# Depth measurement #951
# 4662 --> 4666
# (increased)
#
# Depth measurement #952
# 4666 --> 4657
# (decreased)
#
# Depth measurement #953
# 4657 --> 4661
# (increased)
#
# Depth measurement #954
# 4661 --> 4668
# (increased)
#
# Depth measurement #955
# 4668 --> 4661
# (decreased)
#
# Depth measurement #956
# 4661 --> 4663
# (increased)
#
# Depth measurement #957
# 4663 --> 4664
# (increased)
#
# Depth measurement #958
# 4664 --> 4687
# (increased)
#
# Depth measurement #959
# 4687 --> 4697
# (increased)
#
# Depth measurement #960
# 4697 --> 4710
# (increased)
#
# Depth measurement #961
# 4710 --> 4735
# (increased)
#
# Depth measurement #962
# 4735 --> 4742
# (increased)
#
# Depth measurement #963
# 4742 --> 4764
# (increased)
#
# Depth measurement #964
# 4764 --> 4765
# (increased)
#
# Depth measurement #965
# 4765 --> 4774
# (increased)
#
# Depth measurement #966
# 4774 --> 4763
# (decreased)
#
# Depth measurement #967
# 4763 --> 4786
# (increased)
#
# Depth measurement #968
# 4786 --> 4787
# (increased)
#
# Depth measurement #969
# 4787 --> 4805
# (increased)
#
# Depth measurement #970
# ...
# 8209 --> 8210
# (increased)
#
# Depth measurement #1687
# 8210 --> 8213
# (increased)
#
# Depth measurement #1688
# 8213 --> 8217
# (increased)
#
# Depth measurement #1689
# 8217 --> 8234
# (increased)
#
# Depth measurement #1690
# 8234 --> 8235
# (increased)
#
# Depth measurement #1691
# 8235 --> 8239
# (increased)
#
# Depth measurement #1692
# 8239 --> 8240
# (increased)
#
# Depth measurement #1693
# 8240 --> 8242
# (increased)
#
# Depth measurement #1694
# 8242 --> 8223
# (decreased)
#
# Depth measurement #1695
# 8223 --> 8218
# (decreased)
#
# Depth measurement #1696
# 8218 --> 8233
# (increased)
#
# Depth measurement #1697
# 8233 --> 8236
# (increased)
#
# Depth measurement #1698
# 8236 --> 8247
# (increased)
#
# Depth measurement #1699
# 8247 --> 8249
# (increased)
#
# Depth measurement #1700
# 8249 --> 8252
# (increased)
#
# Depth measurement #1701
# 8252 --> 8253
# (increased)
#
# Depth measurement #1702
# 8253 --> 8259
# (increased)
#
# Depth measurement #1703
# 8259 --> 8276
# (increased)
#
# Depth measurement #1704
# 8276 --> 8299
# (increased)
#
# Depth measurement #1705
# 8299 --> 8303
# (increased)
#
# Depth measurement #1706
# 8303 --> 8309
# (increased)
#
# Depth measurement #1707
# 8309 --> 8310
# (increased)
#
# Depth measurement #1708
# 8310 --> 8315
# (increased)
#
# Depth measurement #1709
# 8315 --> 8321
# (increased)
#
# Depth measurement #1710
# 8321 --> 8319
# (decreased)
#
# Depth measurement #1711
# 8319 --> 8321
# (increased)
#
# Depth measurement #1712
# 8321 --> 8323
# (increased)
#
# Depth measurement #1713
# 8323 --> 8324
# (increased)
#
# Depth measurement #1714
# 8324 --> 8325
# (increased)
#
# Depth measurement #1715
# 8325 --> 8335
# (increased)
#
# Depth measurement #1716
# 8335 --> 8333
# (decreased)
#
# Depth measurement #1717
# 8333 --> 8335
# (increased)
#
# Depth measurement #1718
# 8335 --> 8334
# (decreased)
#
# Depth measurement #1719
# 8334 --> 8335
# (increased)
#
# Depth measurement #1720
# 8335 --> 8336
# (increased)
#
# Depth measurement #1721
# 8336 --> 8352
# (increased)
#
# Depth measurement #1722
# 8352 --> 8360
# (increased)
#
# Depth measurement #1723
# 8360 --> 8367
# (increased)
#
# Depth measurement #1724
# 8367 --> 8370
# (increased)
#
# Depth measurement #1725
# 8370 --> 8371
# (increased)
#
# Depth measurement #1726
# 8371 --> 8374
# (increased)
#
# Depth measurement #1727
# 8374 --> 8386
# (increased)
#
# Depth measurement #1728
# 8386 --> 8388
# (increased)
#
# Depth measurement #1729
# 8388 --> 8399
# (increased)
#
# Depth measurement #1730
# 8399 --> 8402
# (increased)
#
# Depth measurement #1731
# 8402 --> 8403
# (increased)
#
# Depth measurement #1732
# 8403 --> 8404
# (increased)
#
# Depth measurement #1733
# 8404 --> 8405
# (increased)
#
# Depth measurement #1734
# 8405 --> 8409
# (increased)
#
# Depth measurement #1735
# 8409 --> 8446
# (increased)
#
# Depth measurement #1736
# 8446 --> 8449
# (increased)
#
# Depth measurement #1737
# 8449 --> 8469
# (increased)
#
# Depth measurement #1738
# 8469 --> 8470
# (increased)
#
# Depth measurement #1739
# 8470 --> 8471
# (increased)
#
# Depth measurement #1740
# 8471 --> 8469
# (decreased)
#
# Depth measurement #1741
# 8469 --> 8460
# (decreased)
#
# Depth measurement #1742
# 8460 --> 8463
# (increased)
#
# Depth measurement #1743
# 8463 --> 8485
# (increased)
#
# Depth measurement #1744
# 8485 --> 8482
# (decreased)
#
# Depth measurement #1745
# 8482 --> 8470
# (decreased)
#
# Depth measurement #1746
# 8470 --> 8472
# (increased)
#
# Depth measurement #1747
# 8472 --> 8455
# (decreased)
#
# Depth measurement #1748
# 8455 --> 8454
# (decreased)
#
# Depth measurement #1749
# 8454 --> 8447
# (decreased)
#
# Depth measurement #1750
# 8447 --> 8448
# (increased)
#
# Depth measurement #1751
# 8448 --> 8450
# (increased)
#
# Depth measurement #1752
# 8450 --> 8462
# (increased)
#
# Depth measurement #1753
# 8462 --> 8463
# (increased)
#
# Depth measurement #1754
# 8463 --> 8476
# (increased)
#
# Depth measurement #1755
# 8476 --> 8507
# (increased)
#
# Depth measurement #1756
# 8507 --> 8510
# (increased)
#
# Depth measurement #1757
# 8510 --> 8518
# (increased)
#
# Depth measurement #1758
# 8518 --> 8527
# (increased)
#
# Depth measurement #1759
# 8527 --> 8539
# (increased)
#
# Depth measurement #1760
# 8539 --> 8550
# (increased)
#
# Depth measurement #1761
# 8550 --> 8561
# (increased)
#
# Depth measurement #1762
# 8561 --> 8559
# (decreased)
#
# Depth measurement #1763
# 8559 --> 8562
# (increased)
#
# Depth measurement #1764
# 8562 --> 8577
# (increased)
#
# Depth measurement #1765
# 8577 --> 8581
# (increased)
#
# Depth measurement #1766
# 8581 --> 8607
# (increased)
#
# Depth measurement #1767
# 8607 --> 8620
# (increased)
#
# Depth measurement #1768
# 8620 --> 8628
# (increased)
#
# Depth measurement #1769
# 8628 --> 8629
# (increased)
#
# Depth measurement #1770
# 8629 --> 8627
# (decreased)
#
# Depth measurement #1771
# 8627 --> 8636
# (increased)
#
# Depth measurement #1772
# 8636 --> 8644
# (increased)
#
# Depth measurement #1773
# 8644 --> 8637
# (decreased)
#
# Depth measurement #1774
# 8637 --> 8655
# (increased)
#
# Depth measurement #1775
# 8655 --> 8656
# (increased)
#
# Depth measurement #1776
# 8656 --> 8692
# (increased)
#
# Depth measurement #1777
# 8692 --> 8719
# (increased)
#
# Depth measurement #1778
# 8719 --> 8720
# (increased)
#
# Depth measurement #1779
# 8720 --> 8721
# (increased)
#
# Depth measurement #1780
# 8721 --> 8738
# (increased)
#
# Depth measurement #1781
# 8738 --> 8741
# (increased)
#
# Depth measurement #1782
# 8741 --> 8742
# (increased)
#
# Depth measurement #1783
# 8742 --> 8744
# (increased)
#
# Depth measurement #1784
# 8744 --> 8747
# (increased)
#
# Depth measurement #1785
# 8747 --> 8737
# (decreased)
#
# Depth measurement #1786
# 8737 --> 8735
# (decreased)
#
# Depth measurement #1787
# 8735 --> 8736
# (increased)
#
# Depth measurement #1788
# 8736 --> 8743
# (increased)
#
# Depth measurement #1789
# 8743 --> 8749
# (increased)
#
# Depth measurement #1790
# 8749 --> 8758
# (increased)
#
# Depth measurement #1791
# 8758 --> 8761
# (increased)
#
# Depth measurement #1792
# 8761 --> 8763
# (increased)
#
# Depth measurement #1793
# 8763 --> 8794
# (increased)
#
# Depth measurement #1794
# 8794 --> 8793
# (decreased)
#
# Depth measurement #1795
# 8793 --> 8804
# (increased)
#
# Depth measurement #1796
# 8804 --> 8807
# (increased)
#
# Depth measurement #1797
# 8807 --> 8808
# (increased)
#
# Depth measurement #1798
# 8808 --> 8806
# (decreased)
#
# Depth measurement #1799
# 8806 --> 8831
# (increased)
#
# Depth measurement #1800
# 8831 --> 8841
# (increased)
#
# Depth measurement #1801
# 8841 --> 8832
# (decreased)
#
# Depth measurement #1802
# 8832 --> 8835
# (increased)
#
# Depth measurement #1803
# 8835 --> 8843
# (increased)
#
# Depth measurement #1804
# 8843 --> 8825
# (decreased)
#
# Depth measurement #1805
# 8825 --> 8826
# (increased)
#
# Depth measurement #1806
# 8826 --> 8840
# (increased)
#
# Depth measurement #1807
# 8840 --> 8844
# (increased)
#
# Depth measurement #1808
# 8844 --> 8845
# (increased)
#
# Depth measurement #1809
# 8845 --> 8855
# (increased)
#
# Depth measurement #1810
# 8855 --> 8858
# (increased)
#
# Depth measurement #1811
# 8858 --> 8879
# (increased)
#
# Depth measurement #1812
# 8879 --> 8882
# (increased)
#
# Depth measurement #1813
# 8882 --> 8893
# (increased)
#
# Depth measurement #1814
# 8893 --> 8895
# (increased)
#
# Depth measurement #1815
# 8895 --> 8900
# (increased)
#
# Depth measurement #1816
# 8900 --> 8906
# (increased)
#
# Depth measurement #1817
# 8906 --> 8917
# (increased)
#
# Depth measurement #1818
# 8917 --> 8921
# (increased)
#
# Depth measurement #1819
# 8921 --> 8922
# (increased)
#
# Depth measurement #1820
# 8922 --> 8931
# (increased)
#
# Depth measurement #1821
# 8931 --> 8932
# (increased)
#
# Depth measurement #1822
# 8932 --> 8934
# (increased)
#
# Depth measurement #1823
# 8934 --> 8937
# (increased)
#
# Depth measurement #1824
# 8937 --> 8939
# (increased)
#
# Depth measurement #1825
# 8939 --> 8955
# (increased)
#
# Depth measurement #1826
# 8955 --> 8949
# (decreased)
#
# Depth measurement #1827
# 8949 --> 8950
# (increased)
#
# Depth measurement #1828
# 8950 --> 8952
# (increased)
#
# Depth measurement #1829
# 8952 --> 8953
# (increased)
#
# Depth measurement #1830
# 8953 --> 8963
# (increased)
#
# Depth measurement #1831
# 8963 --> 8964
# (increased)
#
# Depth measurement #1832
# 8964 --> 8989
# (increased)
#
# Depth measurement #1833
# 8989 --> 8993
# (increased)
#
# Depth measurement #1834
# 8993 --> 8998
# (increased)
#
# Depth measurement #1835
# 8998 --> 9002
# (increased)
#
# Depth measurement #1836
# 9002 --> 8999
# (decreased)
#
# Depth measurement #1837
# 8999 --> 9001
# (increased)
#
# Depth measurement #1838
# 9001 --> 9002
# (increased)
#
# Depth measurement #1839
# 9002 --> 9016
# (increased)
#
# Depth measurement #1840
# 9016 --> 9024
# (increased)
#
# Depth measurement #1841
# 9024 --> 9029
# (increased)
#
# Depth measurement #1842
# 9029 --> 9032
# (increased)
#
# Depth measurement #1843
# 9032 --> 9031
# (decreased)
#
# Depth measurement #1844
# 9031 --> 9039
# (increased)
#
# Depth measurement #1845
# 9039 --> 9049
# (increased)
#
# Depth measurement #1846
# 9049 --> 9030
# (decreased)
#
# Depth measurement #1847
# 9030 --> 9033
# (increased)
#
# Depth measurement #1848
# 9033 --> 9035
# (increased)
#
# Depth measurement #1849
# 9035 --> 9036
# (increased)
#
# Depth measurement #1850
# 9036 --> 9044
# (increased)
#
# Depth measurement #1851
# 9044 --> 9051
# (increased)
#
# Depth measurement #1852
# 9051 --> 9052
# (increased)
#
# Depth measurement #1853
# 9052 --> 9057
# (increased)
#
# Depth measurement #1854
# 9057 --> 9067
# (increased)
#
# Depth measurement #1855
# 9067 --> 9092
# (increased)
#
# Depth measurement #1856
# 9092 --> 9101
# (increased)
#
# Depth measurement #1857
# 9101 --> 9123
# (increased)
#
# Depth measurement #1858
# 9123 --> 9130
# (increased)
#
# Depth measurement #1859
# 9130 --> 9124
# (decreased)
#
# Depth measurement #1860
# 9124 --> 9133
# (increased)
#
# Depth measurement #1861
# 9133 --> 9143
# (increased)
#
# Depth measurement #1862
# 9143 --> 9149
# (increased)
#
# Depth measurement #1863
# 9149 --> 9172
# (increased)
#
# Depth measurement #1864
# 9172 --> 9173
# (increased)
#
# Depth measurement #1865
# 9173 --> 9178
# (increased)
#
# Depth measurement #1866
# 9178 --> 9193
# (increased)
#
# Depth measurement #1867
# 9193 --> 9184
# (decreased)
#
# Depth measurement #1868
# 9184 --> 9189
# (increased)
#
# Depth measurement #1869
# 9189 --> 9169
# (decreased)
#
# Depth measurement #1870
# 9169 --> 9186
# (increased)
#
# Depth measurement #1871
# 9186 --> 9187
# (increased)
#
# Depth measurement #1872
# 9187 --> 9189
# (increased)
#
# Depth measurement #1873
# 9189 --> 9195
# (increased)
#
# Depth measurement #1874
# 9195 --> 9197
# (increased)
#
# Depth measurement #1875
# 9197 --> 9198
# (increased)
#
# Depth measurement #1876
# 9198 --> 9196
# (decreased)
#
# Depth measurement #1877
# 9196 --> 9218
# (increased)
#
# Depth measurement #1878
# 9218 --> 9219
# (increased)
#
# Depth measurement #1879
# 9219 --> 9235
# (increased)
#
# Depth measurement #1880
# 9235 --> 9267
# (increased)
#
# Depth measurement #1881
# 9267 --> 9271
# (increased)
#
# Depth measurement #1882
# 9271 --> 9273
# (increased)
#
# Depth measurement #1883
# 9273 --> 9278
# (increased)
#
# Depth measurement #1884
# 9278 --> 9289
# (increased)
#
# Depth measurement #1885
# 9289 --> 9290
# (increased)
#
# Depth measurement #1886
# 9290 --> 9307
# (increased)
#
# Depth measurement #1887
# 9307 --> 9319
# (increased)
#
# Depth measurement #1888
# 9319 --> 9324
# (increased)
#
# Depth measurement #1889
# 9324 --> 9328
# (increased)
#
# Depth measurement #1890
# 9328 --> 9342
# (increased)
#
# Depth measurement #1891
# 9342 --> 9343
# (increased)
#
# Depth measurement #1892
# 9343 --> 9344
# (increased)
#
# Depth measurement #1893
# 9344 --> 9348
# (increased)
#
# Depth measurement #1894
# 9348 --> 9360
# (increased)
#
# Depth measurement #1895
# 9360 --> 9366
# (increased)
#
# Depth measurement #1896
# 9366 --> 9373
# (increased)
#
# Depth measurement #1897
# 9373 --> 9397
# (increased)
#
# Depth measurement #1898
# 9397 --> 9392
# (decreased)
#
# Depth measurement #1899
# 9392 --> 9393
# (increased)
#
# Depth measurement #1900
# 9393 --> 9409
# (increased)
#
# Depth measurement #1901
# 9409 --> 9411
# (increased)
#
# Depth measurement #1902
# 9411 --> 9409
# (decreased)
#
# Depth measurement #1903
# 9409 --> 9421
# (increased)
#
# Depth measurement #1904
# 9421 --> 9430
# (increased)
#
# Depth measurement #1905
# 9430 --> 9451
# (increased)
#
# Depth measurement #1906
# 9451 --> 9452
# (increased)
#
# Depth measurement #1907
# 9452 --> 9453
# (increased)
#
# Depth measurement #1908
# 9453 --> 9456
# (increased)
#
# Depth measurement #1909
# 9456 --> 9457
# (increased)
#
# Depth measurement #1910
# 9457 --> 9466
# (increased)
#
# Depth measurement #1911
# 9466 --> 9467
# (increased)
#
# Depth measurement #1912
# 9467 --> 9470
# (increased)
#
# Depth measurement #1913
# 9470 --> 9496
# (increased)
#
# Depth measurement #1914
# 9496 --> 9500
# (increased)
#
# Depth measurement #1915
# 9500 --> 9515
# (increased)
#
# Depth measurement #1916
# 9515 --> 9518
# (increased)
#
# Depth measurement #1917
# 9518 --> 9514
# (decreased)
#
# Depth measurement #1918
# 9514 --> 9534
# (increased)
#
# Depth measurement #1919
# 9534 --> 9541
# (increased)
#
# Depth measurement #1920
# 9541 --> 9542
# (increased)
#
# Depth measurement #1921
# 9542 --> 9545
# (increased)
#
# Depth measurement #1922
# 9545 --> 9551
# (increased)
#
# Depth measurement #1923
# 9551 --> 9583
# (increased)
#
# Depth measurement #1924
# 9583 --> 9581
# (decreased)
#
# Depth measurement #1925
# 9581 --> 9573
# (decreased)
#
# Depth measurement #1926
# 9573 --> 9588
# (increased)
#
# Depth measurement #1927
# 9588 --> 9601
# (increased)
#
# Depth measurement #1928
# 9601 --> 9591
# (decreased)
#
# Depth measurement #1929
# 9591 --> 9592
# (increased)
#
# Depth measurement #1930
# 9592 --> 9593
# (increased)
#
# Depth measurement #1931
# 9593 --> 9600
# (increased)
#
# Depth measurement #1932
# 9600 --> 9599
# (decreased)
#
# Depth measurement #1933
# 9599 --> 9605
# (increased)
#
# Depth measurement #1934
# 9605 --> 9610
# (increased)
#
# Depth measurement #1935
# 9610 --> 9612
# (increased)
#
# Depth measurement #1936
# 9612 --> 9614
# (increased)
#
# Depth measurement #1937
# 9614 --> 9627
# (increased)
#
# Depth measurement #1938
# 9627 --> 9629
# (increased)
#
# Depth measurement #1939
# 9629 --> 9630
# (increased)
#
# Depth measurement #1940
# 9630 --> 9636
# (increased)
#
# Depth measurement #1941
# 9636 --> 9637
# (increased)
#
# Depth measurement #1942
# 9637 --> 9638
# (increased)
#
# Depth measurement #1943
# 9638 --> 9639
# (increased)
#
# Depth measurement #1944
# 9639 --> 9640
# (increased)
#
# Depth measurement #1945
# 9640 --> 9643
# (increased)
#
# Depth measurement #1946
# 9643 --> 9635
# (decreased)
#
# Depth measurement #1947
# 9635 --> 9637
# (increased)
#
# Depth measurement #1948
# 9637 --> 9645
# (increased)
#
# Depth measurement #1949
# 9645 --> 9649
# (increased)
#
# Depth measurement #1950
# 9649 --> 9650
# (increased)
#
# Depth measurement #1951
# 9650 --> 9647
# (decreased)
#
# Depth measurement #1952
# 9647 --> 9648
# (increased)
#
# Depth measurement #1953
# 9648 --> 9652
# (increased)
#
# Depth measurement #1954
# 9652 --> 9653
# (increased)
#
# Depth measurement #1955
# 9653 --> 9663
# (increased)
#
# Depth measurement #1956
# 9663 --> 9656
# (decreased)
#
# Depth measurement #1957
# 9656 --> 9661
# (increased)
#
# Depth measurement #1958
# 9661 --> 9687
# (increased)
#
# Depth measurement #1959
# 9687 --> 9688
# (increased)
#
# Depth measurement #1960
# 9688 --> 9689
# (increased)
#
# Depth measurement #1961
# 9689 --> 9690
# (increased)
#
# Depth measurement #1962
# 9690 --> 9694
# (increased)
#
# Depth measurement #1963
# 9694 --> 9695
# (increased)
#
# Depth measurement #1964
# 9695 --> 9702
# (increased)
#
# Depth measurement #1965
# 9702 --> 9703
# (increased)
#
# Depth measurement #1966
# 9703 --> 9705
# (increased)
#
# Depth measurement #1967
# 9705 --> 9711
# (increased)
#
# Depth measurement #1968
# 9711 --> 9714
# (increased)
#
# Depth measurement #1969
# 9714 --> 9718
# (increased)
#
# Depth measurement #1970
# 9718 --> 9742
# (increased)
#
# Depth measurement #1971
# 9742 --> 9768
# (increased)
#
# Depth measurement #1972
# 9768 --> 9747
# (decreased)
#
# Depth measurement #1973
# 9747 --> 9757
# (increased)
#
# Depth measurement #1974
# 9757 --> 9758
# (increased)
#
# Depth measurement #1975
# 9758 --> 9768
# (increased)
#
# Depth measurement #1976
# 9768 --> 9771
# (increased)
#
# Depth measurement #1977
# 9771 --> 9768
# (decreased)
#
# Depth measurement #1978
# 9768 --> 9772
# (increased)
#
# Depth measurement #1979
# 9772 --> 9779
# (increased)
#
# Depth measurement #1980
# 9779 --> 9780
# (increased)
#
# Depth measurement #1981
# 9780 --> 9785
# (increased)
#
# Depth measurement #1982
# 9785 --> 9804
# (increased)
#
# Depth measurement #1983
# 9804 --> 9805
# (increased)
#
# Depth measurement #1984
# 9805 --> 9803
# (decreased)
#
# Depth measurement #1985
# 9803 --> 9801
# (decreased)
#
# Depth measurement #1986
# 9801 --> 9802
# (increased)
#
# Depth measurement #1987
# 9802 --> 9810
# (increased)
#
# Depth measurement #1988
# 9810 --> 9816
# (increased)
#
# Depth measurement #1989
# 9816 --> 9820
# (increased)
#
# Depth measurement #1990
# 9820 --> 9810
# (decreased)
#
# Depth measurement #1991
# 9810 --> 9815
# (increased)
#
# Depth measurement #1992
# 9815 --> 9816
# (increased)
#
# Depth measurement #1993
# 9816 --> 9823
# (increased)
#
# Depth measurement #1994
# 9823 --> 9824
# (increased)
#
# Depth measurement #1995
# 9824 --> 9830
# (increased)
#
# Depth measurement #1996
# 9830 --> 9831
# (increased)
#
# Depth measurement #1997
# 9831 --> 9841
# (increased)
#
# Depth measurement #1998
# 9841 --> 9860
# (increased)
#
# Depth measurement #1999
# 9860 --> 9875
# (increased)

# %%
print(f"There are {increased} measurements that are larger than the previous measurement.")
# Out:
# There are 1722 measurements that are larger than the previous measurement.

# %% [markdown]
# ## Part 2
